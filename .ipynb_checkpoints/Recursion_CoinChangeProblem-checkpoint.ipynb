# %% [markdown]
# ## Coin change problem

# %% [raw]
# Given  X coins with a certain amount attached to it, what is the least number of coins needed to get get amount Y.

# %%
X=[25,10,5,1] #quarter,dime,nickel,penny

Y=5
sumList=[]
sum=0
def coinRecursion(n):
    global sum
    #quarter=n-25
    #dime=n-10
    #nickel=n-5
    #penny=n-1
    quarter=n-3
    dime=n-2
    nickel=n-1
    #penny=n-1
   
    if(quarter>0):
    
        print(quarter)
       # global sum
        sum=sum+1
        print("this is greater than 0 sum for quarter",sum)
        coinRecursion(quarter)
    
    elif(quarter==0):
        print(quarter)
       # global sum
        sum=sum+1
        print("This is equal to zero sum for quarter",sum)
        sumList.append(sum)
        print(sumList)
        sum=sum-1
        print("Turning sum to zero for quarter",sum)
    
    else:
        print(quarter)
        #global sum
        #sum=0
        
        print("This is less than 0 for quarter",sum)
        
    
    if(dime>0):
    
        print(dime)
        #global sum
        sum=sum+1
        print("this is greater than 0 sum for dime",sum)
        coinRecursion(dime)
    
    elif(dime==0):
        print(dime)
        #global sum
        sum=sum+1
        print("This is equal to zero sum for dime",sum)
        sumList.append(sum)
        print(sumList)
        sum=sum-1
        print("Turning sum to zero for dime",sum)
    
    else:
        print(dime)
       # global sum
        #sum=0
        print("This is less than 0 for dime",sum)
    
        
    if(nickel>0):
        
        print(nickel)
        #global sum
        sum=sum +1
        print("this is greater than 0 sum for nickel",sum)
        coinRecursion(nickel)
    elif(nickel==0):
        print(nickel)
        #global sum
        sum=sum+1
        print("This is equal to zero sum for nickel",sum)
        print(sum)
        sumList.append(sum)
        print(sumList)
        sum=sum-1
        print("Turning sum to zero for nickel",sum)
    
    else:
        print(nickel)
        #global sum
        #sum=0
        print("This is less than 0 for dime",sum)
   # if(penny>0):
    
      # print(penny)
        #coinRecursion(penny)
    
    #else:
       # print(penny)
    
        
        
    
    
    
    
coinRecursion(Y)

print(sumList)
# Out:
# 2
# this is greater than 0 sum for quarter 1
# -1
# This is less than 0 for quarter 1
# 0
# This is equal to zero sum for dime 2
# [2]
# Turning sum to zero for dime 1
# 1
# this is greater than 0 sum for nickel 2
# -2
# This is less than 0 for quarter 2
# -1
# This is less than 0 for dime 2
# 0
# This is equal to zero sum for nickel 3
# 3
# [2, 3]
# Turning sum to zero for nickel 2
# 3
# this is greater than 0 sum for dime 3
# 0
# This is equal to zero sum for quarter 4
# [2, 3, 4]
# Turning sum to zero for quarter 3
# 1
# this is greater than 0 sum for dime 4
# -2
# This is less than 0 for quarter 4
# -1
# This is less than 0 for dime 4
# 0
# This is equal to zero sum for nickel 5
# 5
# [2, 3, 4, 5]
# Turning sum to zero for nickel 4
# 2
# this is greater than 0 sum for nickel 5
# -1
# This is less than 0 for quarter 5
# 0
# This is equal to zero sum for dime 6
# [2, 3, 4, 5, 6]
# Turning sum to zero for dime 5
# 1
# this is greater than 0 sum for nickel 6
# -2
# ...
